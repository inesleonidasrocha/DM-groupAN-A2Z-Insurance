# %%
#!pip install pyreadstat
# Out:
# ...
#      |████████████████████████████████| 585 kB 1.5 MB/s eta 0:00:01
# ...

# %%
import numpy as np

# %%
import pyreadstat
df, meta = pyreadstat.read_sas7bdat('a2z_insurance.sas7bdat')

# %%
df.head()
# Out:
#    CustID  FirstPolYear  BirthYear          EducDeg  MonthSal  GeoLivArea  \
# 0     1.0        1985.0     1982.0  2 - High School    2177.0         1.0
# 1     2.0        1981.0     1995.0  2 - High School     677.0         4.0
# 2     3.0        1991.0     1970.0        1 - Basic    2277.0         3.0
# 3     4.0        1990.0     1981.0      3 - BSc/MSc    1099.0         4.0
# 4     5.0        1986.0     1973.0      3 - BSc/MSc    1763.0         4.0
#
#    Children  CustMonVal  ClaimsRate  PremMotor  PremHousehold  PremHealth  \
# 0       1.0      380.97        0.39     375.85          79.45      146.36
# 1       1.0     -131.13        1.12      77.46         416.20      116.69
# 2       0.0      504.67        0.28     206.15         224.50      124.58
# 3       1.0      -16.99        0.99     182.48          43.35      311.17
# 4       1.0       35.23        0.90     338.62          47.80      182.59
#
#    PremLife  PremWork
# 0     47.01     16.89
# 1    194.48    106.13
# ...

# %%
df.set_index('CustID')
# Out:
#          FirstPolYear  BirthYear          EducDeg  MonthSal  GeoLivArea  \
# CustID
# 1.0            1985.0     1982.0  2 - High School    2177.0         1.0
# 2.0            1981.0     1995.0  2 - High School     677.0         4.0
# 3.0            1991.0     1970.0        1 - Basic    2277.0         3.0
# 4.0            1990.0     1981.0      3 - BSc/MSc    1099.0         4.0
# 5.0            1986.0     1973.0      3 - BSc/MSc    1763.0         4.0
# ...               ...        ...              ...       ...         ...
# 10292.0        1984.0     1949.0          4 - PhD    3188.0         2.0
# 10293.0        1977.0     1952.0        1 - Basic    2431.0         3.0
# 10294.0        1994.0     1976.0      3 - BSc/MSc    2918.0         1.0
# 10295.0        1981.0     1977.0        1 - Basic    1971.0         2.0
# 10296.0        1990.0     1981.0          4 - PhD    2815.0         1.0
#
#          Children  CustMonVal  ClaimsRate  PremMotor  PremHousehold  \
# CustID
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10296 entries, 0 to 10295
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CustID         10296 non-null  float64
#  1   FirstPolYear   10266 non-null  float64
#  2   BirthYear      10279 non-null  float64
#  3   EducDeg        10296 non-null  object
#  4   MonthSal       10260 non-null  float64
#  5   GeoLivArea     10295 non-null  float64
#  6   Children       10275 non-null  float64
#  7   CustMonVal     10296 non-null  float64
#  8   ClaimsRate     10296 non-null  float64
#  9   PremMotor      10262 non-null  float64
#  10  PremHousehold  10296 non-null  float64
#  11  PremHealth     10253 non-null  float64
#  12  PremLife       10192 non-null  float64
#  13  PremWork       10210 non-null  float64
# dtypes: float64(13), object(1)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#             CustID  FirstPolYear     BirthYear      MonthSal    GeoLivArea  \
# count  10296.00000  10266.000000  10279.000000  10260.000000  10295.000000
# mean    5148.50000   1991.062634   1968.007783   2506.667057      2.709859
# std     2972.34352    511.267913     19.709476   1157.449634      1.266291
# min        1.00000   1974.000000   1028.000000    333.000000      1.000000
# 25%     2574.75000   1980.000000   1953.000000   1706.000000      1.000000
# 50%     5148.50000   1986.000000   1968.000000   2501.500000      3.000000
# 75%     7722.25000   1992.000000   1983.000000   3290.250000      4.000000
# max    10296.00000  53784.000000   2001.000000  55215.000000      4.000000
#
#            Children     CustMonVal    ClaimsRate     PremMotor  PremHousehold  \
# count  10275.000000   10296.000000  10296.000000  10262.000000   10296.000000
# mean       0.706764     177.892605      0.742772    300.470252     210.431192
# ...

# %%
df['BirthYear'].sort_values(ascending=True).head() #temos este 1028 que n faz sentido nenhum
# Out:
# 7195    1028.0
# 7440    1935.0
# 7956    1935.0
# 329     1935.0
# 3454    1935.0
# Name: BirthYear, dtype: float64

# %%
df[['FirstPolYear','BirthYear']]
# Out:
#        FirstPolYear  BirthYear
# 0            1985.0     1982.0
# 1            1981.0     1995.0
# 2            1991.0     1970.0
# 3            1990.0     1981.0
# 4            1986.0     1973.0
# ...             ...        ...
# 10291        1984.0     1949.0
# 10292        1977.0     1952.0
# 10293        1994.0     1976.0
# 10294        1981.0     1977.0
# 10295        1990.0     1981.0
#
# [10296 rows x 2 columns]

# %%
df[df['FirstPolYear'] <= df['BirthYear']]
# Out:
#         CustID  FirstPolYear  BirthYear          EducDeg  MonthSal  \
# 1          2.0        1981.0     1995.0  2 - High School     677.0
# 13        14.0        1983.0     2000.0        1 - Basic    1043.0
# 18        19.0        1981.0     1982.0        1 - Basic    1414.0
# 20        21.0        1986.0     1986.0          4 - PhD    1704.0
# 22        23.0        1976.0     1986.0  2 - High School    1495.0
# ...        ...           ...        ...              ...       ...
# 10268  10269.0        1987.0     1988.0      3 - BSc/MSc    1414.0
# 10273  10274.0        1989.0     1992.0  2 - High School    1035.0
# 10284  10285.0        1980.0     1987.0      3 - BSc/MSc    1504.0
# 10288  10289.0        1982.0     1993.0  2 - High School    1465.0
# 10290  10291.0        1994.0     1999.0        1 - Basic     626.0
#
#        GeoLivArea  Children  CustMonVal  ClaimsRate  PremMotor  PremHousehold  \
# 1             4.0       1.0     -131.13        1.12      77.46         416.20
# ...
