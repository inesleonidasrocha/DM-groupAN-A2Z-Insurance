# %% [markdown]
# <div class="alert alert-block alert-info" style = "background:#d0de6f; color:#000000; border:0;">
#
# # Table of Contents
#
# </div>
#
# 1. [Imports](#Imports)
# 2. [Load Datasets](#Load_Datasets)
# <!--     1. [Sub paragraph](#subparagraph1) -->
# 3. [Data Exploration](#Exploration)
# 4. [Data Cleaning](#Cleaning)
# 5. [Feature Selection](#Feature_Selection)
# 6. [Models](#Models)
# 7. [Comparison and Model Choice](#Comparison_Model)
# 8. [Prepare Test Data](#Prepare_Test)

# %%
import os
os.environ["PATH"] += os.pathsep + 'D:/Program Files (x86)/Graphviz2.38/bin/'

# %% [markdown]
# ### Tarefas :)
# - missing values - ines  5)
# - outliers - isa     6)
# - inconsistencias - ir pondo   2)
# - feature selection - ines    8)
# <p><s>- tipos de variáveis - joana  1)</s></p>
# <p><s>- PCA - joana    11)</s></p>
# - fazer variáveis novas - ines      4)
# - gráficos, histogramas, correlações - isa  3)
# - heatmap -isa      7)
# - relatório lmao - todas :D
# <p><s>- scale data,</s></p>
# - ordinal encoder    9)
# <p><s>- dummify - joana    10)</s></p>
# -
#
# HII

# %% [markdown]
# <div class="alert alert-block alert-info" style = "background:#d0de6f; color:#000000; border:0;">
#
# # 1. Imports
#
# <a name="Imports"></a>
# </div>

# %%
#!pip install pyreadstat

# %%
import numpy as np
import pandas as pd
import pyreadstat
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
import numpy as np
import warnings
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
warnings.filterwarnings('ignore')

# %% [markdown]
# <div class="alert alert-block alert-info" style = "background:#d0de6f; color:#000000; border:0;">
#
# # 2. Load Datasets
#
# <a name="Load_Datasets"></a>
# </div>

# %%
df, meta = pyreadstat.read_sas7bdat('a2z_insurance.sas7bdat')

# %%
df.head()
# Out:
#    CustID  FirstPolYear  BirthYear          EducDeg  MonthSal  GeoLivArea  \
# 0     1.0        1985.0     1982.0  2 - High School    2177.0         1.0
# 1     2.0        1981.0     1995.0  2 - High School     677.0         4.0
# 2     3.0        1991.0     1970.0        1 - Basic    2277.0         3.0
# 3     4.0        1990.0     1981.0      3 - BSc/MSc    1099.0         4.0
# 4     5.0        1986.0     1973.0      3 - BSc/MSc    1763.0         4.0
#
#    Children  CustMonVal  ClaimsRate  PremMotor  PremHousehold  PremHealth  \
# 0       1.0      380.97        0.39     375.85          79.45      146.36
# 1       1.0     -131.13        1.12      77.46         416.20      116.69
# 2       0.0      504.67        0.28     206.15         224.50      124.58
# 3       1.0      -16.99        0.99     182.48          43.35      311.17
# 4       1.0       35.23        0.90     338.62          47.80      182.59
#
#    PremLife  PremWork
# 0     47.01     16.89
# 1    194.48    106.13
# 2     86.35     99.02
# 3     35.34     28.34
# 4     18.78     41.45

# %%
#Check for dupicate rows
df['CustID'].nunique()
# Out:
# 10296

# %%
df.set_index('CustID', inplace = True)

# %% [markdown]
# <div class="alert alert-block alert-info" style = "background:#d0de6f; color:#000000; border:0;">
#
# # 3. Data Exploration
#
# <a name="Exploration"></a>
# </div>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 10296 entries, 1.0 to 10296.0
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   FirstPolYear   10266 non-null  float64
#  1   BirthYear      10279 non-null  float64
#  2   EducDeg        10296 non-null  object
#  3   MonthSal       10260 non-null  float64
#  4   GeoLivArea     10295 non-null  float64
#  5   Children       10275 non-null  float64
#  6   CustMonVal     10296 non-null  float64
#  7   ClaimsRate     10296 non-null  float64
#  8   PremMotor      10262 non-null  float64
#  9   PremHousehold  10296 non-null  float64
#  10  PremHealth     10253 non-null  float64
#  11  PremLife       10192 non-null  float64
#  12  PremWork       10210 non-null  float64
# dtypes: float64(12), object(1)
# memory usage: 1.1+ MB

# %% [markdown]
# From here we can see that some variables are keep as float although thats is not the most appropiate variable type for them. We are going to correct them now so we can explore the data easier. We can also see that we have a lot of variables with missing values.

# %%
df.isnull().sum()
# Out:
# FirstPolYear      30
# BirthYear         17
# EducDeg            0
# MonthSal          36
# GeoLivArea         1
# Children          21
# CustMonVal         0
# ClaimsRate         0
# PremMotor         34
# PremHousehold      0
# PremHealth        43
# PremLife         104
# PremWork          86
# dtype: int64

# %% [markdown]
# ### Changing Data Types

# %% [markdown]
# The variables <code>BirthYear</code>, <code>FirstPolYear</code>, <code>GeoLivArea</code> and <code>Children</code> are discrete, so they should be integers.

# %%
df[(round(df['BirthYear']) != df['BirthYear'])]
# Out:
#         FirstPolYear  BirthYear          EducDeg  MonthSal  GeoLivArea  \
# CustID
# 420.0         1987.0        NaN  2 - High School    3219.0         1.0
# 756.0            NaN        NaN          4 - PhD    2913.0         3.0
# 1874.0        1995.0        NaN        1 - Basic     517.0         1.0
# 1929.0        1983.0        NaN  2 - High School    2426.0         4.0
# 2562.0        1976.0        NaN  2 - High School    3253.0         1.0
# 2706.0        1978.0        NaN      3 - BSc/MSc    3614.0         4.0
# 3182.0        1987.0        NaN  2 - High School    3954.0         2.0
# 3284.0        1983.0        NaN      3 - BSc/MSc    2433.0         1.0
# 3761.0           NaN        NaN  2 - High School    2067.0         1.0
# 5040.0        1994.0        NaN  2 - High School    1769.0         4.0
# 5191.0           NaN        NaN      3 - BSc/MSc    2772.0         1.0
# 6873.0        1986.0        NaN  2 - High School    2846.0         1.0
# 7138.0        1988.0        NaN        1 - Basic    4028.0         1.0
# 7758.0        1995.0        NaN  2 - High School    1612.0         1.0
# 7968.0        1975.0        NaN  2 - High School    2958.0         4.0
# 8924.0        1989.0        NaN          4 - PhD    2432.0         4.0
# 9007.0        1978.0        NaN  2 - High School    1572.0         4.0
#
#         Children  CustMonVal  ClaimsRate  PremMotor  PremHousehold  \
# CustID
# 420.0        1.0      379.30        0.33     404.52          42.80
# 756.0        0.0      430.20        0.28     465.20          59.45
# 1874.0       1.0     -238.93        1.19      63.68         692.90
# 1929.0       1.0      163.80        0.74     286.83         158.35
# 2562.0       1.0      -44.44        1.03     298.61          13.90
# 2706.0       0.0      356.96        0.54     381.96         274.50
# 3182.0       0.0      -25.00        1.00     233.60         206.70
# 3284.0       1.0      289.06        0.52     321.84          83.90
# 3761.0       1.0      -47.67        1.04     495.87          58.90
# 5040.0       1.0      262.49        0.60     221.71         153.35
# 5191.0       0.0      -25.00        1.00     326.84         216.15
# 6873.0       1.0       88.92        0.83     449.75         117.25
# 7138.0       0.0      820.72        0.28     103.13         735.70
# 7758.0       1.0      311.76        0.39     264.05         -16.10
# 7968.0       1.0      253.83        0.65     372.18         230.60
# 8924.0       1.0      581.88        0.13     468.31         118.90
# 9007.0       1.0      128.47        0.84     187.59         457.30
#
#         PremHealth  PremLife  PremWork
# CustID
# 420.0       152.25      7.78     -0.11
# 756.0        94.13      4.89     10.00
# 1874.0       98.13    151.14    126.47
# 1929.0      181.48     72.57     30.45
# 2562.0      191.37     49.01     33.34
# 2706.0      117.91     35.45     12.89
# 3182.0      265.94     36.45     21.67
# 3284.0      238.60      3.89      3.89
# 3761.0       61.90     22.67      3.78
# 5040.0      262.05     44.23     43.34
# 5191.0      164.03     45.23     13.67
# 6873.0       88.35     26.56     -1.11
# 7138.0      156.14     88.35     95.24
# 7758.0      154.25     49.12    104.91
# 7968.0      111.80     48.23     23.67
# 8924.0       84.35     19.67      5.89
# 9007.0      155.03     65.90    100.02

# %%
df['BirthYear'] = df['BirthYear'].astype('Int32')
df['BirthYear'].dtype
# Out:
# Int32Dtype()

# %%
#see if there are any years in which the value is a float (has decimals) - which would be an inconsistency
df[(round(df['FirstPolYear']) != df['FirstPolYear'])]
# Out:
#          FirstPolYear  BirthYear          EducDeg  MonthSal  GeoLivArea  \
# CustID
# 297.0             NaN       1955          4 - PhD    3591.0         NaN
# 756.0             NaN       <NA>          4 - PhD    2913.0         3.0
# 897.0             NaN       1960                     2643.0         1.0
# 2228.0            NaN       1979      3 - BSc/MSc    1987.0         2.0
# 2450.0            NaN       1939                     4465.0         4.0
# 2704.0            NaN       1977        1 - Basic    2105.0         2.0
# 2729.0            NaN       1954                     3200.0         2.0
# 2771.0            NaN       1984                     1473.0         4.0
# 2927.0            NaN       1982      3 - BSc/MSc    1817.0         2.0
# 3057.0            NaN       1977                     2221.0         1.0
# 3761.0            NaN       <NA>  2 - High School    2067.0         1.0
# 4088.0            NaN       1964        1 - Basic       NaN         1.0
# 4424.0            NaN       1962                     2688.0         1.0
# 5159.0            NaN       1956      3 - BSc/MSc       NaN         1.0
# 5191.0            NaN       <NA>      3 - BSc/MSc    2772.0         1.0
# 6536.0            NaN       1968                     2413.0         3.0
# 6864.0            NaN       1992      3 - BSc/MSc    1291.0         2.0
# 6904.0            NaN       1953  2 - High School    2645.0         2.0
# 6985.0            NaN       1992      3 - BSc/MSc    1208.0         1.0
# 7322.0            NaN       1942                     3346.0         4.0
# 7471.0            NaN       1949                     3211.0         4.0
# 7475.0            NaN       1964          4 - PhD    2198.0         2.0
# 8082.0            NaN       1940                     4216.0         4.0
# 8174.0            NaN       1951                     4183.0         1.0
# 8304.0            NaN       1938                     3729.0         3.0
# 9137.0            NaN       1993                     1753.0         1.0
# 9313.0            NaN       1974                     2552.0         1.0
# 9325.0            NaN       1971  2 - High School    1942.0         2.0
# 9611.0            NaN       1964                     2905.0         1.0
# 10011.0           NaN       1947  2 - High School    3959.0         2.0
#
#          Children  CustMonVal  ClaimsRate  PremMotor  PremHousehold  \
# CustID
# 297.0         NaN      -49.11        1.04     447.64         -25.00
# 756.0         0.0      430.20        0.28     465.20          59.45
# 897.0         1.0      -25.00        1.00     515.54          33.90
# 2228.0        NaN      429.87        0.25     376.85          33.90
# 2450.0        0.0      457.75        0.36     338.73         187.25
# 2704.0        NaN      302.62        0.54     299.28         167.25
# 2729.0        0.0      109.25        0.77     211.93          14.45
# 2771.0        1.0      443.74        0.31     386.74         104.45
# 2927.0        NaN      420.32        0.26     466.42         -10.55
# 3057.0        1.0       -9.22        0.97     475.09          15.00
# 3761.0        1.0      -47.67        1.04     495.87          58.90
# 4088.0        1.0      -25.00        1.00     266.94         240.60
# 4424.0        1.0      481.99        0.09     533.99         -30.00
# 5159.0        1.0       52.57        0.91     231.60         381.75
# 5191.0        0.0      -25.00        1.00     326.84         216.15
# 6536.0        1.0      420.86        0.28     472.31          48.35
# 6864.0        NaN      -28.78        1.00     104.24         926.85
# 6904.0        1.0      575.01        0.35     229.60         431.20
# 6985.0        1.0      -43.45        1.03     431.08          48.90
# 7322.0        0.0      173.47        0.73     139.47         177.80
# 7471.0        0.0      261.50        0.66     213.82         323.95
# 7475.0        NaN      -90.00        1.12     561.66         -50.00
# 8082.0        1.0      320.40        0.56     376.96         212.25
# 8174.0        0.0      173.04        0.75     178.59         246.70
# 8304.0        0.0       17.45        0.93     254.38          63.90
# 9137.0        1.0      464.86        0.41      49.23         280.60
# 9313.0        1.0      458.20        0.28     468.31         102.25
# 9325.0        NaN      366.19        0.38     306.28          73.35
# 9611.0        1.0      -70.34        1.06     273.72         211.70
# 10011.0       NaN     -128.24        1.14     177.81         153.35
#
#          PremHealth  PremLife  PremWork
# CustID
# 297.0        130.58      0.89     12.89
# 756.0         94.13      4.89     10.00
# 897.0         47.01     12.89      3.78
# 2228.0       154.25     39.34      4.78
# 2450.0       175.81     43.23      4.78
# 2704.0       162.92     28.34     51.01
# 2729.0       275.72     77.68     11.67
# 2771.0       156.92      5.00     27.45
# 2927.0       112.91     12.89     16.89
# 3057.0        93.35     15.78      2.78
# 3761.0        61.90     22.67      3.78
# 4088.0       189.59     36.34     45.01
# 4424.0        52.01      3.00       NaN
# 5159.0       195.48     20.56     57.01
# 5191.0       164.03     45.23     13.67
# 6536.0        56.90     26.45     16.67
# 6864.0       146.25     78.46     74.68
# 6904.0       161.14     60.79     42.23
# 6985.0       123.69     13.67      4.78
# 7322.0       281.61    120.80     20.67
# 7471.0       197.26     37.34     74.79
# 7475.0        24.45     -4.00     11.00
# 8082.0       158.14     11.78     31.56
# 8174.0       251.38     50.12     69.57
# 8304.0       290.61     11.67     21.45
# 9137.0       172.70    163.92    160.03
# 9313.0        79.46      6.78     14.89
# 9325.0       222.82     15.67     11.56
# 9611.0       229.60      9.89     45.34
# 10011.0      311.28     67.79     35.45

# %%
df['FirstPolYear'] = df['FirstPolYear'].astype('Int32')
df['FirstPolYear'].dtype
# Out:
# Int32Dtype()

# %%
#see if there are any geograhic areas in which the value is a float (has decimals)
df[(round(df['GeoLivArea']) != df['GeoLivArea'])]
# Out:
#         FirstPolYear  BirthYear  EducDeg  MonthSal  GeoLivArea  Children  \
# CustID
# 297.0           <NA>       1955  4 - PhD    3591.0         NaN       NaN
#
#         CustMonVal  ClaimsRate  PremMotor  PremHousehold  PremHealth  \
# CustID
# 297.0       -49.11        1.04     447.64          -25.0      130.58
#
#         PremLife  PremWork
# CustID
# 297.0       0.89     12.89

# %%
df['GeoLivArea'] = df['GeoLivArea'].astype('Int32')
df['GeoLivArea'].dtype
# Out:
# Int32Dtype()

# %%
#see if there are any children in which the value is a float (has decimals)
df[(round(df['Children']) != df['Children'])]
# Out:
#          FirstPolYear  BirthYear          EducDeg  MonthSal  GeoLivArea  \
# CustID
# 297.0            <NA>       1955          4 - PhD    3591.0        <NA>
# 620.0            1980       1994      3 - BSc/MSc    1333.0           2
# 773.0            1998       1949  2 - High School    3601.0           2
# 2228.0           <NA>       1979      3 - BSc/MSc    1987.0           2
# 2363.0           1981       1975  2 - High School    1607.0           2
# 2672.0           1992       1988  2 - High School    1140.0           2
# 2704.0           <NA>       1977        1 - Basic    2105.0           2
# 2927.0           <NA>       1982      3 - BSc/MSc    1817.0           2
# 3178.0           1980       1975      3 - BSc/MSc    2647.0           2
# 3281.0           1980       1949  2 - High School    3509.0           2
# 3685.0           1992       1959        1 - Basic    3086.0           2
# 4729.0           1979       1964        1 - Basic    2740.0           2
# 5438.0           1976       1982      3 - BSc/MSc    1817.0           2
# 6472.0           1988       1952  2 - High School    3228.0           2
# 6864.0           <NA>       1992      3 - BSc/MSc    1291.0           2
# 7475.0           <NA>       1964          4 - PhD    2198.0           2
# 8019.0           1982       1963      3 - BSc/MSc    2699.0           2
# 8375.0           1993       1998        1 - Basic     924.0           2
# 8420.0           1976       1966      3 - BSc/MSc    2884.0           2
# 9325.0           <NA>       1971  2 - High School    1942.0           2
# 10011.0          <NA>       1947  2 - High School    3959.0           2
#
#          Children  CustMonVal  ClaimsRate  PremMotor  PremHousehold  \
# CustID
# 297.0         NaN      -49.11        1.04     447.64         -25.00
# 620.0         NaN      312.52        0.40     286.83          -6.10
# 773.0         NaN       27.01        0.94     104.91         308.95
# 2228.0        NaN      429.87        0.25     376.85          33.90
# 2363.0        NaN      271.51        0.64     292.61         308.40
# 2672.0        NaN      356.40        0.54     168.03         265.60
# 2704.0        NaN      302.62        0.54     299.28         167.25
# 2927.0        NaN      420.32        0.26     466.42         -10.55
# 3178.0        NaN      392.19        0.37     404.41         107.25
# 3281.0        NaN      253.61        0.59     170.70         161.15
# 3685.0        NaN      -92.68        1.09     367.07         147.80
# 4729.0        NaN      -27.89        1.00     480.20          88.35
# 5438.0        NaN      -37.00        1.02     372.85         186.70
# 6472.0        NaN      294.95        0.62     319.95         328.95
# 6864.0        NaN      -28.78        1.00     104.24         926.85
# 7475.0        NaN      -90.00        1.12     561.66         -50.00
# 8019.0        NaN      434.66        0.16     509.54         -25.55
# 8375.0        NaN     -245.93        1.20      58.01         612.90
# 8420.0        NaN      533.10        0.08     529.10          25.00
# 9325.0        NaN      366.19        0.38     306.28          73.35
# 10011.0       NaN     -128.24        1.14     177.81         153.35
#
#          PremHealth  PremLife  PremWork
# CustID
# 297.0        130.58      0.89     12.89
# 620.0        175.70     52.90     56.79
# 773.0        285.61     64.90     52.90
# 2228.0       154.25     39.34      4.78
# 2363.0       159.14     11.89     59.68
# 2672.0       273.94     68.79     52.23
# 2704.0       162.92     28.34     51.01
# 2927.0       112.91     12.89     16.89
# 3178.0       110.80     24.56     12.78
# 3281.0       229.60      5.78    113.69
# 3685.0       124.80      9.78     67.68
# 4729.0        83.35      5.89      2.89
# 5438.0       146.25     13.78      1.78
# 6472.0       131.47     62.90      6.78
# 6864.0       146.25     78.46     74.68
# 7475.0        24.45     -4.00     11.00
# 8019.0        72.68     -1.11     -7.00
# 8375.0       190.48     45.23    175.70
# 8420.0        50.01     -1.00      5.00
# 9325.0       222.82     15.67     11.56
# 10011.0      311.28     67.79     35.45

# %%
df['Children'] = df['Children'].astype('Int32')
df['Children'].dtype
# Out:
# Int32Dtype()

# %% [markdown]
# ### Continuing with data exploration

# %%
df.describe()
# Out:
#        FirstPolYear     BirthYear      MonthSal    GeoLivArea      Children  \
# count  10266.000000  10279.000000  10260.000000  10295.000000  10275.000000
# mean    1991.062634   1968.007783   2506.667057      2.709859      0.706764
# std      511.267913     19.709476   1157.449634      1.266291      0.455268
# min     1974.000000   1028.000000    333.000000      1.000000      0.000000
# 25%     1980.000000   1953.000000   1706.000000      1.000000      0.000000
# 50%     1986.000000   1968.000000   2501.500000      3.000000      1.000000
# 75%     1992.000000   1983.000000   3290.250000      4.000000      1.000000
# max    53784.000000   2001.000000  55215.000000      4.000000      1.000000
#
#           CustMonVal    ClaimsRate     PremMotor  PremHousehold    PremHealth  \
# count   10296.000000  10296.000000  10262.000000   10296.000000  10253.000000
# mean      177.892605      0.742772    300.470252     210.431192    171.580833
# std      1945.811505      2.916964    211.914997     352.595984    296.405976
# min   -165680.420000      0.000000     -4.110000     -75.000000     -2.110000
# 25%        -9.440000      0.390000    190.590000      49.450000    111.800000
# 50%       186.870000      0.720000    298.610000     132.800000    162.810000
# 75%       399.777500      0.980000    408.300000     290.050000    219.820000
# max     11875.890000    256.200000  11604.420000   25048.800000  28272.000000
#
#            PremLife      PremWork
# count  10192.000000  10210.000000
# mean      41.855782     41.277514
# std       47.480632     51.513572
# min       -7.000000    -12.000000
# 25%        9.890000     10.670000
# 50%       25.560000     25.670000
# 75%       57.790000     56.790000
# max      398.300000   1988.700000

# %% [markdown]
# The variable <code>BirthYear</code> has an impossible minimum value. The variable <code>FirstPolYear</code> also has a impossible maximum value.

# %%
 df.describe(include="O").T
# Out:
#          count unique          top  freq
# EducDeg  10296      5  3 - BSc/MSc  4799

# %% [markdown]
# ### Check inconsistencies

# %%
df['BirthYear'].sort_values(ascending=True).head() #temos este 1028 que n faz sentido nenhum
# Out:
# CustID
# 7196.0    1028
# 7441.0    1935
# 7957.0    1935
# 330.0     1935
# 3455.0    1935
# Name: BirthYear, dtype: Int32

# %% [markdown]
# We only have one value that does not make sense: 1024. Now we want to see if there are people that have their FirstPolYear before the BirthYear

# %%
df[df['FirstPolYear'] < (df['BirthYear']-1)]
# Out:
#          FirstPolYear  BirthYear          EducDeg  MonthSal  GeoLivArea  \
# CustID
# 2.0              1981       1995  2 - High School     677.0           4
# 14.0             1983       2000        1 - Basic    1043.0           3
# 23.0             1976       1986  2 - High School    1495.0           1
# 45.0             1985       1990      3 - BSc/MSc    1065.0           1
# 47.0             1976       1986      3 - BSc/MSc    1219.0           4
# ...               ...        ...              ...       ...         ...
# 10268.0          1977       1996        1 - Basic     834.0           4
# 10274.0          1989       1992  2 - High School    1035.0           1
# 10285.0          1980       1987      3 - BSc/MSc    1504.0           4
# 10289.0          1982       1993  2 - High School    1465.0           1
# 10291.0          1994       1999        1 - Basic     626.0           3
#
#          Children  CustMonVal  ClaimsRate  PremMotor  PremHousehold  \
# CustID
# 2.0             1     -131.13        1.12      77.46         416.20
# 14.0            1      -75.12        1.06      44.34         342.85
# 23.0            1      -89.79        1.08     209.04         308.95
# 45.0            1     -128.68        1.19     111.80         -35.00
# 47.0            1      -94.90        1.08     269.94         300.60
# ...           ...         ...         ...        ...            ...
# 10268.0         1      254.72        0.67     181.48         309.50
# 10274.0         1      293.51        0.58     235.71         195.60
# 10285.0         1       -1.55        0.96     390.63          29.45
# 10289.0         1      795.15        0.35      67.79         820.15
# 10291.0         1      176.26        0.85       6.89         878.50
#
#          PremHealth  PremLife  PremWork
# CustID
# 2.0          116.69    194.48    106.13
# 14.0         127.69    267.94     94.46
# 23.0         192.48     64.79     54.90
# 45.0         208.26    224.71     44.23
# 47.0         143.25     59.79     69.90
# ...             ...       ...       ...
# 10268.0      134.58    114.80     98.24
# 10274.0      103.13    170.92     58.12
# 10285.0      179.70     -6.00       NaN
# 10289.0      102.13    182.48     86.46
# 10291.0      103.13    113.02    201.26
#
# [1845 rows x 13 columns]

# %% [markdown]
# There are 2160 people that have policies that were done before they were even born.

# %%
df[(df['BirthYear'] >2000) & (df['PremHousehold']>0)]
# Out:
#         FirstPolYear  BirthYear    EducDeg  MonthSal  GeoLivArea  Children  \
# CustID
# 660.0           1991       2001  1 - Basic    1284.0           4         1
# 690.0           1997       2001  1 - Basic    1180.0           3         1
# 866.0           1979       2001  1 - Basic     562.0           1         1
# 1437.0          1989       2001  1 - Basic     823.0           4         0
# 2580.0          1986       2001  1 - Basic    1006.0           4         0
# 3147.0          1994       2001  1 - Basic     372.0           4         1
# 4466.0          1978       2001  1 - Basic     958.0           4         0
# 4484.0          1983       2001  1 - Basic    1241.0           3         1
# 5348.0          1980       2001  1 - Basic    1119.0           3         1
# 5608.0          1974       2001  1 - Basic    1131.0           3         0
# 8963.0          1978       2001  1 - Basic    1117.0           4         0
# 9907.0          1976       2001  1 - Basic    1422.0           1         1
#
#         CustMonVal  ClaimsRate  PremMotor  PremHousehold  PremHealth  \
# CustID
# 660.0       243.50        0.81      46.23        1079.65       72.68
# 690.0       436.10        0.48      54.90         406.20       65.79
# 866.0      1113.78        0.11      40.34         847.95       94.24
# 1437.0      281.28        0.60     129.58         177.80       58.01
# 2580.0      267.95        0.67      48.23         396.75      291.50
# 3147.0      488.76        0.36      60.68         270.60      177.59
# 4466.0     -204.59        1.11      28.56        1359.15       68.79
# 4484.0      909.17        0.13      43.34         589.55      142.47
# 5348.0      796.71        0.23     148.14         628.45      221.82
# 5608.0      -25.00        1.00      43.23         690.70      157.03
# 8963.0     1280.58        0.11      19.56        1109.10       55.90
# 9907.0      467.31        0.37      69.68         231.15      201.26
#
#         PremLife  PremWork
# CustID
# 660.0     252.27    -10.00
# 690.0     112.02    256.05
# 866.0     178.70    112.13
# 1437.0    176.70    218.15
# 2580.0    127.58     24.45
# 3147.0    182.48    107.13
# 4466.0     38.23    179.59
# 4484.0    121.80    179.48
# 5348.0     45.12     30.23
# 5608.0     87.35    142.25
# 8963.0    230.82     53.90
# 9907.0    191.48     82.35

# %%
df.groupby('EducDeg')['BirthYear'].max()
# Out:
# EducDeg
#                    1993
# 1 - Basic          2001
# 2 - High School    1998
# 3 - BSc/MSc        1996
# 4 - PhD            1993
# Name: BirthYear, dtype: Int32

# %%
df[(df['MonthSal'] <0)]
# Out:
# Empty DataFrame
# Columns: [FirstPolYear, BirthYear, EducDeg, MonthSal, GeoLivArea, Children, CustMonVal, ClaimsRate, PremMotor, PremHousehold, PremHealth, PremLife, PremWork]
# Index: []

# %%
df[(df['ClaimsRate'] <0)]
# Out:
# Empty DataFrame
# Columns: [FirstPolYear, BirthYear, EducDeg, MonthSal, GeoLivArea, Children, CustMonVal, ClaimsRate, PremMotor, PremHousehold, PremHealth, PremLife, PremWork]
# Index: []

# %% [markdown]
# ### Value Counts

# %%
for col in df.columns:
    if df[col].dtype!="float64":
        print('-' * 40 + col + '-' * 40 , end=' - ')
        display(df[col].value_counts(dropna=False))
# Out:
# ----------------------------------------FirstPolYear---------------------------------------- -
# 1988     512
# 1994     475
# 1993     473
# 1989     466
# 1984     464
# 1986     458
# 1977     453
# 1978     453
# 1992     451
# 1990     449
# 1981     445
# 1995     445
# 1982     444
# 1979     443
# 1996     440
# 1987     438
# 1976     433
# 1980     432
# 1991     430
# 1985     429
# 1983     423
# 1975     285
# 1997     271
# 1974     141
# 1998     112
# <NA>      30
# 53784      1
# Name: FirstPolYear, dtype: Int64
# ----------------------------------------BirthYear---------------------------------------- -
# 1962    206
# 1968    200
# 1964    194
# 1953    193
# 1981    190
#        ...
# 2000     35
# <NA>     17
# 1935     14
# 2001     12
# 1028      1
# Name: BirthYear, Length: 69, dtype: Int64
# ----------------------------------------EducDeg---------------------------------------- -
# 3 - BSc/MSc        4799
# 2 - High School    3510
# 1 - Basic          1272
# 4 - PhD             698
#                      17
# Name: EducDeg, dtype: int64
# ----------------------------------------GeoLivArea---------------------------------------- -
# 4       4145
# 1       3048
# 3       2066
# 2       1036
# <NA>       1
# Name: GeoLivArea, dtype: Int64
# ----------------------------------------Children---------------------------------------- -
# 1       7262
# 0       3013
# <NA>      21
# Name: Children, dtype: Int64

# %%
df[df['EducDeg']==""]
# Out:
#         FirstPolYear  BirthYear EducDeg  MonthSal  GeoLivArea  Children  \
# CustID
# 897.0           <NA>       1960            2643.0           1         1
# 1708.0          1992       1946            3827.0           4         0
# 2450.0          <NA>       1939            4465.0           4         0
# 2729.0          <NA>       1954            3200.0           2         0
# 2771.0          <NA>       1984            1473.0           4         1
# 3057.0          <NA>       1977            2221.0           1         1
# 4424.0          <NA>       1962            2688.0           1         1
# 6536.0          <NA>       1968            2413.0           3         1
# 6561.0          1976       1992               NaN           4         1
# 7322.0          <NA>       1942            3346.0           4         0
# 7471.0          <NA>       1949            3211.0           4         0
# 8082.0          <NA>       1940            4216.0           4         1
# 8174.0          <NA>       1951            4183.0           1         0
# 8304.0          <NA>       1938            3729.0           3         0
# 9137.0          <NA>       1993            1753.0           1         1
# 9313.0          <NA>       1974            2552.0           1         1
# 9611.0          <NA>       1964            2905.0           1         1
#
#         CustMonVal  ClaimsRate  PremMotor  PremHousehold  PremHealth  \
# CustID
# 897.0       -25.00        1.00     515.54          33.90       47.01
# 1708.0      355.52        0.33     222.71         146.70         NaN
# 2450.0      457.75        0.36     338.73         187.25      175.81
# 2729.0      109.25        0.77     211.93          14.45      275.72
# 2771.0      443.74        0.31     386.74         104.45      156.92
# 3057.0       -9.22        0.97     475.09          15.00       93.35
# 4424.0      481.99        0.09     533.99         -30.00       52.01
# 6536.0      420.86        0.28     472.31          48.35       56.90
# 6561.0       85.91        0.77      91.24           0.00      227.60
# 7322.0      173.47        0.73     139.47         177.80      281.61
# 7471.0      261.50        0.66     213.82         323.95      197.26
# 8082.0      320.40        0.56     376.96         212.25      158.14
# 8174.0      173.04        0.75     178.59         246.70      251.38
# 8304.0       17.45        0.93     254.38          63.90      290.61
# 9137.0      464.86        0.41      49.23         280.60      172.70
# 9313.0      458.20        0.28     468.31         102.25       79.46
# 9611.0      -70.34        1.06     273.72         211.70      229.60
#
#         PremLife  PremWork
# CustID
# 897.0      12.89      3.78
# 1708.0     94.13    105.24
# 2450.0     43.23      4.78
# 2729.0     77.68     11.67
# 2771.0      5.00     27.45
# 3057.0     15.78      2.78
# 4424.0      3.00       NaN
# 6536.0     26.45     16.67
# 6561.0     60.01    110.91
# 7322.0    120.80     20.67
# 7471.0     37.34     74.79
# 8082.0     11.78     31.56
# 8174.0     50.12     69.57
# 8304.0     11.67     21.45
# 9137.0    163.92    160.03
# 9313.0      6.78     14.89
# 9611.0      9.89     45.34

# %% [markdown]
# <p>The variable <code>FirstPolYear</code> has one person with the impossible value of 53784.</p>
# <p>The variable <code>BirthYear</code> has one person with the impossible value of 1028.</p>
# <p>The variable <code>EducDeg</code> has 17 missing values that are cells that are completly blank, but are not encoded as NaN  </p>

# %%
#making the blank spaces in education a nan
df.replace("", np.nan, inplace=True)

# %%
df['EducDeg'].value_counts(dropna=False)
# Out:
# 3 - BSc/MSc        4799
# 2 - High School    3510
# 1 - Basic          1272
# 4 - PhD             698
# NaN                  17
# Name: EducDeg, dtype: int64

# %% [markdown]
# ### Distribuition Graphs

# %%
for col in df.columns:
    if df[col].dtype=="float64":
        fig=plt.figure()
        df.boxplot(col)

# %% [markdown]
# From the previous output there are several conclusions we can take:
# - MonthSal: has extreme values (above 30000€). These values are considered outliers, because they are very far from the rest of the distribution.
# - CustMonVal: has a skewed distribution. There is an extreme outlier below -150000€.
# - ClaimsRate: also has a very skewed distribution, with an outlier above 250
# - PremMotor: has several outliers, we can consider above 6000 as an outlier, for example
# - PremHousehold: it is a skewed distribution with an extreme outlier 25000+
# - PremLife: has a skewed distribution but doesn't seem to have many outliers
# - PremWork: has a skewed distribution, with one outlier, above 1750.
#
# In the outlier section we will explore these outliers in more depth and decide on how to handle them.

# %%
for col in df.columns:
    if df[col].dtype=="float64":
        fig=plt.figure()
        sns.histplot(data=df, x=col, binwidth=3)

# %%
sns.histplot(data=df, x="MonthSal", binwidth=3)
plt.xlim(None, 8000)
plt.show()

# %% [markdown]
# After zooming in the histogram, we can see that the variable *MonthSal* has an almost Normal distribution

# %%
sns.histplot(data=df, x="CustMonVal", binwidth=3)
plt.xlim(-500, 1500)
plt.show()

# %% [markdown]
# We can see from the graph that there is a high number of customers with a specific value below zero

# %%
sns.histplot(data=df, x="ClaimsRate")
plt.xlim(-5, 5)
plt.show()

# %%
df['ClaimsRate'].value_counts()
# Out:
# 1.00     457
# 1.01     212
# 1.02     203
# 0.99     198
# 1.03     195
#         ...
# 96.00      1
# 13.90      1
# 12.60      1
# 35.00      1
# 1.51       1
# Name: ClaimsRate, Length: 165, dtype: int64

# %% [markdown]
# ### Missing Value Detection

# %%
#verify what type of missingness we have
import missingno as msno
msno.matrix(df)
#FirstPolYear and EducDeg are MNAR (Missing Not at Random)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Variable Relationships

# %%
"""
# Pairwise Relationship of Numerical Variables
sns.set()

# Setting pairplot
sns.pairplot(df, diag_kind="hist")

# Layout
plt.subplots_adjust(top=0.95)
plt.suptitle("Pairwise Relationship of Numerical Variables", fontsize=20)

plt.show()"""
# Out:
# '\n# Pairwise Relationship of Numerical Variables\nsns.set()\n\n# Setting pairplot\nsns.pairplot(df, diag_kind="hist")\n\n# Layout\nplt.subplots_adjust(top=0.95)\nplt.suptitle("Pairwise Relationship of Numerical Variables", fontsize=20)\n\nplt.show()'

# %%
# Pairwise Relationship of Numerical Variables
plt.figure(figsize=(10, 8))
heatmap=sns.heatmap(df.corr(), annot=True)
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12);

# %% [markdown]
# From the heatmap above, it is evident that there are some variables that are highly linearly correlated. In the code below those relationships are explored in more detail.

# %%
sns.scatterplot(data=df, x='ClaimsRate', y='CustMonVal')
# Out:
# <AxesSubplot:xlabel='ClaimsRate', ylabel='CustMonVal'>

# %% [markdown]
# According to the metadata:
# - CMV Customer Monetary Value -> Lifetime value = (annual profit from customer) * (nº of years that they are a customer) - (acquisition cost)
# - Claims Rate -> Amount paid by the insurance company (€)/ Premiums (€) Note: in the last 2 years

# %% [markdown]
# Taking the metadata into account, it makes sense that these variables are so correlated. There are some outliers with one being a very extreme one. This is a person that received much more money from the company than they paid, so they are not profitable to the company.

# %%
sns.scatterplot(data=df, x='BirthYear', y='MonthSal')
plt.xlim(1900, None)
plt.ylim(None, 7500)
plt.show()
#see in the range without outliers

# %%
sns.displot(data=df, x='BirthYear', y='Children')
plt.xlim(1900, None)
plt.show()

# %%
sns.scatterplot(data=df, x='PremLife', y='PremMotor')
# Out:
# <AxesSubplot:xlabel='PremLife', ylabel='PremMotor'>

# %% [markdown]
# <div class="alert alert-block alert-info" style = "background:#d0de6f; color:#000000; border:0;">
#
# # 4. Data Cleaning
#
# <a name="Cleaning"></a>
# </div>

# %% [markdown]
# ### New Features

# %% [markdown]
# ### Outliers

# %% [markdown]
# From the previous output there are several conclusions we can take:
# - MonthSal: has extreme values (above 30000€). These values are considered outliers, because they are very far from the rest of the distribution.
# - CustMonVal: has a skewed distribution. There is an extreme outlier below -150000€.
# - ClaimsRate: also has a very skewed distribution, with an outlier above 250
# - PremMotor: has several outliers, we can consider above 6000 as an outlier, for example
# - PremHousehold: it is a skewed distribution with an extreme outlier 25000+
# - PremLife: has a skewed distribution but doesn't seem to have many outliers
# - PremWork: has a skewed distribution, with one outlier, above 1750.
#
# In the outlier section we will explore these outliers in more depth and decide on how to handle them.

# %% [markdown]
# #### MonthSal

# %%
df[df['MonthSal']>30000]
# Out:
#         FirstPolYear  BirthYear          EducDeg  MonthSal  GeoLivArea  \
# CustID
# 5883.0          1995       1956  2 - High School   55215.0           4
# 8262.0          1981       1991  2 - High School   34490.0           4
#
#         Children  CustMonVal  ClaimsRate  PremMotor  PremHousehold  \
# CustID
# 5883.0         1      122.25        0.79     281.83         147.25
# 8262.0         0      608.89        0.28      57.01         358.95
#
#         PremHealth  PremLife  PremWork
# CustID
# 5883.0      130.58     84.46     66.68
# 8262.0      195.26    113.80    161.14

# %% [markdown]
# Since there are only 2 observations with this problem, it will not impact the dataset in a major way. So we can remove them.

# %%
df= df[df['MonthSal']<=30000]

# %% [markdown]
# #### CustMonVal:

# %%
df[df['CustMonVal']<-150000]
# Out:
#         FirstPolYear  BirthYear      EducDeg  MonthSal  GeoLivArea  Children  \
# CustID
# 172.0           1990       1989  3 - BSc/MSc    1086.0           4         1
#
#         CustMonVal  ClaimsRate  PremMotor  PremHousehold  PremHealth  \
# CustID
# 172.0   -165680.42       256.2     378.07           78.9      166.81
#
#         PremLife  PremWork
# CustID
# 172.0       6.89     18.45

# %%
df=df[df['CustMonVal']>=-150000]

# %% [markdown]
# #### ClaimsRate

# %%
df[df['ClaimsRate']>250]
# Out:
# Empty DataFrame
# Columns: [FirstPolYear, BirthYear, EducDeg, MonthSal, GeoLivArea, Children, CustMonVal, ClaimsRate, PremMotor, PremHousehold, PremHealth, PremLife, PremWork]
# Index: []

# %% [markdown]
# The only example of a client with a Claims Rate above 250 was removed in the CustMonVal handling of the outliers.

# %% [markdown]
# #### PremMotor

# %%
df[df['PremMotor']>6000]
# Out:
#         FirstPolYear  BirthYear          EducDeg  MonthSal  GeoLivArea  \
# CustID
# 5212.0          1981       1943  2 - High School    4135.0           3
# 5294.0          1989       1963      3 - BSc/MSc    3564.0           3
#
#         Children  CustMonVal  ClaimsRate  PremMotor  PremHousehold  \
# CustID
# 5212.0         0      130.14        0.99    8744.61          101.7
# 5294.0         1    11875.89        0.09   11604.42           48.9
#
#         PremHealth  PremLife  PremWork
# CustID
# 5212.0     1767.00    155.14    130.58
# 5294.0     1045.52    103.13    296.47

# %%
df=df[df['PremMotor']<=6000]

# %% [markdown]
# #### PremHousehold

# %%
df[df['PremHousehold']>25000]
# Out:
#         FirstPolYear  BirthYear          EducDeg  MonthSal  GeoLivArea  \
# CustID
# 8867.0          1978       1972  2 - High School    2618.0           4
#
#         Children  CustMonVal  ClaimsRate  PremMotor  PremHousehold  \
# CustID
# 8867.0         1      473.54        0.98     508.43        25048.8
#
#         PremHealth  PremLife  PremWork
# CustID
# 8867.0       36.23      9.89     11.89

# %%
df= df[df['PremHousehold']<=25000]

# %% [markdown]
# #### PremWork

# %%
df[df['PremWork']>1750]
# Out:
#         FirstPolYear  BirthYear          EducDeg  MonthSal  GeoLivArea  \
# CustID
# 5085.0          1994       1959  2 - High School    3330.0           3
#
#         Children  CustMonVal  ClaimsRate  PremMotor  PremHousehold  \
# CustID
# 5085.0         0     2314.21        0.14     350.51          201.7
#
#         PremHealth  PremLife  PremWork
# CustID
# 5085.0       125.8     39.23    1988.7

# %%
df=df[df['PremWork']<=1750]

# %% [markdown]
# ### Missing Values

# %% [markdown]
# There are several methods that can be used to handle missing values. We will not drop the rows with missing values, because that constitutes a very substantial percentage of the dataset. Other methods include imputing with the median/mode or KNN imputer, which we tried both.

# %%
df["EducDeg"].replace('', np.nan)
# Out:
# CustID
# 1.0        2 - High School
# 2.0        2 - High School
# 3.0              1 - Basic
# 4.0            3 - BSc/MSc
# 5.0            3 - BSc/MSc
#                 ...
# 10292.0            4 - PhD
# 10293.0          1 - Basic
# 10294.0        3 - BSc/MSc
# 10295.0          1 - Basic
# 10296.0            4 - PhD
# Name: EducDeg, Length: 10150, dtype: object

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=6)
imp = pd.DataFrame(imputer.fit_transform(df.loc[:, df.columns != 'EducDeg']),index=df.index, columns = df.columns[df.columns != 'EducDeg'])
imp["EducDeg"]= df["EducDeg"]
df=imp
df.head()
# Out:
#         FirstPolYear  BirthYear  MonthSal  GeoLivArea  Children  CustMonVal  \
# CustID
# 1.0           1985.0     1982.0    2177.0         1.0       1.0      380.97
# 2.0           1981.0     1995.0     677.0         4.0       1.0     -131.13
# 3.0           1991.0     1970.0    2277.0         3.0       0.0      504.67
# 4.0           1990.0     1981.0    1099.0         4.0       1.0      -16.99
# 5.0           1986.0     1973.0    1763.0         4.0       1.0       35.23
#
#         ClaimsRate  PremMotor  PremHousehold  PremHealth  PremLife  PremWork  \
# CustID
# 1.0           0.39     375.85          79.45      146.36     47.01     16.89
# 2.0           1.12      77.46         416.20      116.69    194.48    106.13
# 3.0           0.28     206.15         224.50      124.58     86.35     99.02
# 4.0           0.99     182.48          43.35      311.17     35.34     28.34
# 5.0           0.90     338.62          47.80      182.59     18.78     41.45
#
#                 EducDeg
# CustID
# 1.0     2 - High School
# 2.0     2 - High School
# 3.0           1 - Basic
# 4.0         3 - BSc/MSc
# 5.0         3 - BSc/MSc

# %%
'''
#df.fillna(0,inplace=True)
from sklearn.impute import SimpleImputer
imp_mean = SimpleImputer(missing_values=np.nan, strategy='median')
df = pd.DataFrame(imp_mean.fit_transform(df.loc[:, df.columns != 'EducDeg']),index=df.index, columns = df.columns[df.columns != 'EducDeg'])
#df['EducDeg'].fillna(df['EducDeg'].mode(),inplace=True)
'''
# Out:
# "\n#df.fillna(0,inplace=True)\nfrom sklearn.impute import SimpleImputer\nimp_mean = SimpleImputer(missing_values=np.nan, strategy='median')\ndf = pd.DataFrame(imp_mean.fit_transform(df.loc[:, df.columns != 'EducDeg']),index=df.index, columns = df.columns[df.columns != 'EducDeg'])\n#df['EducDeg'].fillna(df['EducDeg'].mode(),inplace=True)\n"

# %%
df['EducDeg'].fillna(df['EducDeg'].mode()[0],inplace=True)
df['EducDeg'].isna().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 10150 entries, 1.0 to 10296.0
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   FirstPolYear   10150 non-null  float64
#  1   BirthYear      10150 non-null  float64
#  2   MonthSal       10150 non-null  float64
#  3   GeoLivArea     10150 non-null  float64
#  4   Children       10150 non-null  float64
#  5   CustMonVal     10150 non-null  float64
#  6   ClaimsRate     10150 non-null  float64
#  7   PremMotor      10150 non-null  float64
#  8   PremHousehold  10150 non-null  float64
#  9   PremHealth     10150 non-null  float64
#  10  PremLife       10150 non-null  float64
#  11  PremWork       10150 non-null  float64
#  12  EducDeg        10150 non-null  object
# dtypes: float64(12), object(1)
# memory usage: 1.1+ MB

# %% [markdown]
# ### Scaling of Data

# %%
#Try MinMaxSCaler() and RobustScaler()
from sklearn.preprocessing import MinMaxScaler, RobustScaler
scaler = RobustScaler().fit(df[['BirthYear','FirstPolYear','MonthSal','CustMonVal','ClaimsRate','PremHousehold','PremHealth','PremLife','PremWork','PremMotor']])
# this will return an array
df[['BirthYear','FirstPolYear','MonthSal','CustMonVal','ClaimsRate','PremHousehold','PremHealth','PremLife','PremWork','PremMotor']] = scaler.transform(df[['BirthYear','FirstPolYear','MonthSal','CustMonVal','ClaimsRate','PremHousehold','PremHealth','PremLife','PremWork','PremMotor']])
df.head()
# Out:
#         FirstPolYear  BirthYear  MonthSal  GeoLivArea  Children  CustMonVal  \
# CustID
# 1.0        -0.083333   0.466667 -0.204603         1.0       1.0    0.472265
# 2.0        -0.416667   0.900000 -1.150378         4.0       1.0   -0.780211
# 3.0         0.416667   0.066667 -0.141551         3.0       0.0    0.774806
# 4.0         0.333333   0.433333 -0.884300         4.0       1.0   -0.501052
# 5.0         0.000000   0.166667 -0.465637         4.0       1.0   -0.373334
#
#         ClaimsRate  PremMotor  PremHousehold  PremHealth  PremLife  PremWork  \
# CustID
# 1.0      -0.559322   0.357074      -0.224023   -0.153461  0.447808 -0.193179
# 2.0       0.677966  -1.018439       1.175603   -0.428413  3.526514  1.770297
# 3.0      -0.745763  -0.425206       0.378845   -0.355296  1.269102  1.613861
# 4.0       0.457627  -0.534320      -0.374065    1.373830  0.204175  0.058746
# 5.0       0.305085   0.185452      -0.355569    0.182282 -0.141545  0.347195
#
#                 EducDeg
# CustID
# 1.0     2 - High School
# 2.0     2 - High School
# 3.0           1 - Basic
# 4.0         3 - BSc/MSc
# 5.0         3 - BSc/MSc

# %% [markdown]
# ### Separating Numerical Variables from Categorical/Binary

# %%
df_num=df.select_dtypes('float64')
df_cat = df.select_dtypes(exclude='float64')

# %%
df_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 10150 entries, 1.0 to 10296.0
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   FirstPolYear   10150 non-null  float64
#  1   BirthYear      10150 non-null  float64
#  2   MonthSal       10150 non-null  float64
#  3   GeoLivArea     10150 non-null  float64
#  4   Children       10150 non-null  float64
#  5   CustMonVal     10150 non-null  float64
#  6   ClaimsRate     10150 non-null  float64
#  7   PremMotor      10150 non-null  float64
#  8   PremHousehold  10150 non-null  float64
#  9   PremHealth     10150 non-null  float64
#  10  PremLife       10150 non-null  float64
#  11  PremWork       10150 non-null  float64
# dtypes: float64(12)
# memory usage: 1.0 MB

# %% [markdown]
# ### Get Dummies

# %% [markdown]
# There is only one categorical variable in this dataset. For the algorithms to be able to handle the variable, we can either transform it into various dummy variables:

# %%
df_dummies = pd.get_dummies(df, columns=['EducDeg'], drop_first=True)

# %% [markdown]
# Or we can transform into a numerical variable, since the variable is ordinal. Taking into account that the categories themselves are already numbered, we only need to erase the characters after the number and convert the variable into int type.

# %%
df['EducDeg'] = df['EducDeg'].str.split().str[0]#.astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 10150 entries, 1.0 to 10296.0
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   FirstPolYear   10150 non-null  float64
#  1   BirthYear      10150 non-null  float64
#  2   MonthSal       10150 non-null  float64
#  3   GeoLivArea     10150 non-null  float64
#  4   Children       10150 non-null  float64
#  5   CustMonVal     10150 non-null  float64
#  6   ClaimsRate     10150 non-null  float64
#  7   PremMotor      10150 non-null  float64
#  8   PremHousehold  10150 non-null  float64
#  9   PremHealth     10150 non-null  float64
#  10  PremLife       10150 non-null  float64
#  11  PremWork       10150 non-null  float64
#  12  EducDeg        10150 non-null  object
# dtypes: float64(12), object(1)
# memory usage: 1.1+ MB

# %% [markdown]
# <div class="alert alert-block alert-info" style = "background:#d0de6f; color:#000000; border:0;">
#
# # 5. Feature Selection
#
# <a name="Feature_Selection"></a>
# </div>

# %% [markdown]
# <a class="anchor" id="7th-bullet">
#
# ## 5.1 PCA
#
# <a name="5.1.1"></a>
# </a>

# %%
pca = PCA()
pc = pca.fit_transform(df_num)
plt.plot(pca.explained_variance_ratio_.cumsum(), lw=3, color='#087E8B')
plt.title('Cumulative explained variance by number of principal components', size=10)
plt.show()

# %%
print(pca.explained_variance_ratio_)
# Out:
# [9.85535838e-01 6.91048966e-03 4.08965730e-03 1.21313856e-03
#  8.61113924e-04 3.92735703e-04 3.75238117e-04 3.43916281e-04
#  1.23280873e-04 6.66223834e-05 4.87830858e-05 3.91859364e-05]

# %%
print(pca.explained_variance_ratio_.cumsum())
# Out:
# [0.98553584 0.99244633 0.99653599 0.99774912 0.99861024 0.99900297
#  0.99937821 0.99972213 0.99984541 0.99991203 0.99996081 1.        ]

# %%
loadings = pd.DataFrame(
    data=pca.components_.T * np.sqrt(pca.explained_variance_), 
    columns=[f'PC{i}' for i in range(1, len(df_num.columns) + 1)],
    index=df_num.columns
)

#choosing 3 principal components
loadings.iloc[:,:3]
# Out:
#                      PC1       PC2       PC3
# FirstPolYear   42.848377  0.000562 -0.000071
# BirthYear      -0.006801 -0.012451  0.009650
# MonthSal        0.005007  0.016842 -0.008894
# GeoLivArea     -0.017034 -0.004870  0.004848
# Children       -0.007093 -0.005957 -0.032400
# CustMonVal      0.003877 -2.572317  0.039518
# ClaimsRate     -0.005956  2.500275 -0.008002
# PremMotor       0.002380 -0.012953 -0.133362
# PremHousehold  -0.008051 -0.052720  0.068496
# PremHealth      0.001619  0.045252  2.752547
# PremLife       -0.003888  0.001885  0.049536
# PremWork       -0.004893 -0.008390  0.120113

# %% [markdown]
# <a class="anchor" id="7th-bullet">
#
# ## 5.2 Univariate Variables
#
# <a name="5.1.1"></a>
# </a>

# %%
df.var()
# Out:
# FirstPolYear     1835.983422
# BirthYear           0.433030
# MonthSal            0.385883
# GeoLivArea          1.603933
# Children            0.207399
# CustMonVal          6.670982
# ClaimsRate          6.311025
# PremMotor           0.542902
# PremHousehold       1.117410
# PremHealth          7.588582
# PremLife            0.981414
# PremWork            1.103730
# dtype: float64

# %% [markdown]
# Since all variables have a variance>0, there are no univariate variables. So, all of them reveal some information.

# %% [markdown]
# <a class="anchor" id="7th-bullet">
#
# ## 5.3 Kendall's Correlation
#
# <a name="5.1.2"></a>
# </a>

# %%
df_num=df.select_dtypes('float64')
cor_ = np.round(df_num.corr(method ='kendall'), decimals=3)
# Prepare figure
fig = plt.figure(figsize=(10, 8))

# Build annotation matrix (values above |0.5| will appear annotated in the plot)
mask_annot = np.absolute(cor_.values) >= 0.0
annot = np.where(mask_annot, cor_.values, np.full(cor_.shape,"")) # Try to understand what this np.where() does

# Plot heatmap of the correlation matrix
sns.heatmap(data=cor_, annot=annot, cmap=sns.diverging_palette(220, 10, as_cmap=True), 
            fmt='s', vmin=-1, vmax=1, center=0, square=True, linewidths=.5)

# Layout
fig.subplots_adjust(top=0.95)
fig.suptitle("Correlation Matrix", fontsize=20)

plt.show()

# %% [markdown]
# ### Define perpectives for our data

# %%
#df_insurance =

# %%
#df_customers =
